# %%
import pandas as pd
import numpy as np

# %%
file=pd.read_csv("kc_house_data.csv")
file.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
file.dtypes
# Out:
# id                 int64
# date              object
# price            float64
# bedrooms           int64
# bathrooms        float64
# sqft_living        int64
# sqft_lot           int64
# floors           float64
# waterfront         int64
# view               int64
# condition          int64
# grade              int64
# sqft_above         int64
# sqft_basement      int64
# yr_built           int64
# yr_renovated       int64
# zipcode            int64
# lat              float64
# long             float64
# sqft_living15      int64
# sqft_lot15         int64
# dtype: object

# %%
f1 = file[file.duplicated(keep=False)]
f1
# Out:
# Empty DataFrame
# Columns: [id, date, price, bedrooms, bathrooms, sqft_living, sqft_lot, floors, waterfront, view, condition, grade, sqft_above, sqft_basement, yr_built, yr_renovated, zipcode, lat, long, sqft_living15, sqft_lot15]
# Index: []
#
# [0 rows x 21 columns]

# %%
filter=file.isnull()
filter
# Out:
#           id   date  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# 0      False  False  False     False      False        False     False
# 1      False  False  False     False      False        False     False
# 2      False  False  False     False      False        False     False
# 3      False  False  False     False      False        False     False
# 4      False  False  False     False      False        False     False
# 5      False  False  False     False      False        False     False
# 6      False  False  False     False      False        False     False
# 7      False  False  False     False      False        False     False
# 8      False  False  False     False      False        False     False
# 9      False  False  False     False      False        False     False
# 10     False  False  False     False      False        False     False
# 11     False  False  False     False      False        False     False
# ...

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib.backends.backend_agg import FigureCanvasAgg
from matplotlib.figure import Figure
# Out:
# /home/nbuser/anaconda3_501/lib/python3.6/site-packages/matplotlib/font_manager.py:281: UserWarning: Matplotlib is building the font cache using fc-list. This may take a moment.
#   'Matplotlib is building the font cache using fc-list. '

# %%
file.describe()
# Out:
#                  id         price      bedrooms     bathrooms   sqft_living  \
# count  2.161300e+04  2.161300e+04  21613.000000  21613.000000  21613.000000
# mean   4.580302e+09  5.400881e+05      3.370842      2.114757   2079.899736
# std    2.876566e+09  3.671272e+05      0.930062      0.770163    918.440897
# min    1.000102e+06  7.500000e+04      0.000000      0.000000    290.000000
# 25%    2.123049e+09  3.219500e+05      3.000000      1.750000   1427.000000
# 50%    3.904930e+09  4.500000e+05      3.000000      2.250000   1910.000000
# 75%    7.308900e+09  6.450000e+05      4.000000      2.500000   2550.000000
# max    9.900000e+09  7.700000e+06     33.000000      8.000000  13540.000000
#
#            sqft_lot        floors    waterfront          view     condition  \
# count  2.161300e+04  21613.000000  21613.000000  21613.000000  21613.000000
# mean   1.510697e+04      1.494309      0.007542      0.234303      3.409430
# ...

# %%
file.head()
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
file.columns
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
fig=Figure()
canvas=FigureCanvasAgg(fig)
ax=fig.add_subplot()
for i in range(0,21):
    if i=
plt.plot(file[''],file['zipcode'],'go')
ax=plt.gca()
ax.axis([-100000,100000,100000,100000])
# Out:
#   File "<ipython-input-10-236191192129>", line 5
#     if i=
#         ^
# SyntaxError: invalid syntax

# %%
import statsmodels.formula.api as sm

# %%
model1 = sm.ols(formula='price ~ bedrooms+sqft_living+waterfront+view+grade+yr_renovated+zipcode+lat+long+sqft_living15',data=file).fit()
model1.summary()

# %%
x=pd.DataFrame.corr(file)
print(x<-0.3)
x.get('True')
# Out:
#                   id  price  bedrooms  bathrooms  sqft_living  sqft_lot  \
# id             False  False     False      False        False     False
# price          False  False     False      False        False     False
# bedrooms       False  False     False      False        False     False
# bathrooms      False  False     False      False        False     False
# sqft_living    False  False     False      False        False     False
# sqft_lot       False  False     False      False        False     False
# floors         False  False     False      False        False     False
# waterfront     False  False     False      False        False     False
# view           False  False     False      False        False     False
# condition      False  False     False      False        False     False
# grade          False  False     False      False        False     False
# sqft_above     False  False     False      False        False     False
# ...

# %% [markdown]
# remove id

# %%
model2 = sm.ols(formula='price ~ bedrooms+bathrooms+sqft_living+waterfront+view+condition+grade+sqft_above+sqft_basement+yr_built+zipcode+lat+long+sqft_living15+sqft_lot15',data=file).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.699
# Model:                            OLS   Adj. R-squared:                  0.699
# Method:                 Least Squares   F-statistic:                     3586.
# Date:                Wed, 20 Jun 2018   Prob (F-statistic):               0.00
# Time:                        09:47:22   Log-Likelihood:            -2.9462e+05
# No. Observations:               21613   AIC:                         5.893e+05
# Df Residuals:                   21598   BIC:                         5.894e+05
# Df Model:                          14
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
model2.summary()

# %%
plt.plot(file['grade'],file['price'],'ro')
plt.plot(file['grade'],model5.fittedvalues,'bo')
plt.xlabel('grade')
plt.ylabel('price')
plt.title('Model-5 (price ~ grade)')
plt.show()

# %%
model5.resid
SSE = sum(model5.resid ** 2)
SSE
RMSE = np.sqrt(SSE / len(file))
RMSE
# Out:
# 236733.30137197854

# %% [markdown]
# remove the non effecting factors of the property
# like

# %%
model5 = sm.ols('price~bedrooms+bathrooms+sqft_living+waterfront+grade+sqft_above+sqft_living15',data=file).fit()
model5.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.584
# Model:                            OLS   Adj. R-squared:                  0.584
# Method:                 Least Squares   F-statistic:                     4336.
# Date:                Wed, 20 Jun 2018   Prob (F-statistic):               0.00
# Time:                        08:33:22   Log-Likelihood:            -2.9812e+05
# No. Observations:               21613   AIC:                         5.963e+05
# Df Residuals:                   21605   BIC:                         5.963e+05
# Df Model:                           7
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
plt.plot(file['sqft_living15'],file['sqft_above'],'go')

# %%
np.corrcoef(file['yr_built'],file['bathrooms'])[0][1]
# Out:
# 0.5060194382852531

# %%
l=file.columns
l
sqft living,grade,sqft_living15,sqftabove,bedroom,bathrooms
# Out:
# Index(['id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living',
#        'sqft_lot', 'floors', 'waterfront', 'view', 'condition', 'grade',
#        'sqft_above', 'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode',
#        'lat', 'long', 'sqft_living15', 'sqft_lot15'],
#       dtype='object')

# %%
x=0
def fun(a,b):
    x=np.corrcoef(file [a],file[b])[0][1]

for i in range(0,21):
    for j in range(0,21):
        fun(l[i],l[j])
        if x>0:
            print('analyse these both factors as they change each others effect on price:/n')
            print(l[i],l[j],'/n')
            print(x,'/n')
        else:
            continue
print("done")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-13-5461f618c680> in <module>()
#       5 for i in range(0,21):
#       6     for j in range(0,21):
# ----> 7         fun(l[i],l[j])
#       8         if x>0:
#       9             print('analyse these both factors as they change each others effect on price:/n')
#
# <ipython-input-13-5461f618c680> in fun(a, b)
#       1 x=0
#       2 def fun(a,b):
# ----> 3     x=np.corrcoef(file [a],file[b])[0][1]
#       4
#       5 for i in range(0,21):
#
# ~/anaconda3_501/lib/python3.6/site-packages/numpy/lib/function_base.py in corrcoef(x, y, rowvar, bias, ddof)
#    3173         warnings.warn('bias and ddof have no effect and are deprecated',
#    3174                       DeprecationWarning, stacklevel=2)
# -> 3175     c = cov(x, y, rowvar)
#    3176     try:
#    3177         d = diag(c)
#
# ...

# %% [markdown]
# remove unwanted factors

# %%
model2 = sm.ols(formula='price ~ id+bedrooms+bathrooms+sqft_living+sqft_lot+floors+waterfront+view+condition+grade+sqft_above+sqft_basement+yr_built+yr_renovated+zipcode+lat+long+sqft_living15+sqft_lot15',data=file).fit()
model2.summary()
# Out:
# <class 'statsmodels.iolib.summary.Summary'>
# """
#                             OLS Regression Results
# ...
# Dep. Variable:                  price   R-squared:                       0.700
# Model:                            OLS   Adj. R-squared:                  0.700
# Method:                 Least Squares   F-statistic:                     2797.
# Date:                Wed, 20 Jun 2018   Prob (F-statistic):               0.00
# Time:                        18:10:58   Log-Likelihood:            -2.9460e+05
# No. Observations:               21613   AIC:                         5.892e+05
# Df Residuals:                   21594   BIC:                         5.894e+05
# Df Model:                          18
# Covariance Type:            nonrobust
# ...
#                     coef    std err          t      P>|t|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# ...

# %%
Test = file.head()

# %%
Test
# Out:
#            id             date     price  bedrooms  bathrooms  sqft_living  \
# 0  7129300520  20141013T000000  221900.0         3       1.00         1180
# 1  6414100192  20141209T000000  538000.0         3       2.25         2570
# 2  5631500400  20150225T000000  180000.0         2       1.00          770
# 3  2487200875  20141209T000000  604000.0         4       3.00         1960
# 4  1954400510  20150218T000000  510000.0         3       2.00         1680
#
#    sqft_lot  floors  waterfront  view     ...      grade  sqft_above  \
# 0      5650     1.0           0     0     ...          7        1180
# 1      7242     2.0           0     0     ...          7        2170
# 2     10000     1.0           0     0     ...          6         770
# 3      5000     1.0           0     0     ...          7        1050
# 4      8080     1.0           0     0     ...          8        1680
#
#    sqft_basement  yr_built  yr_renovated  zipcode      lat     long  \
# ...

# %%
predictTest = model2.predict(Test)

# %%
predictTest
# Out:
# 0    205766.264587
# 1    731219.649809
# 2    379097.882635
# 3    457424.134315
# 4    444789.054709
# dtype: float64

# %%
Test['price']
# Out:
# 0    221900.0
# 1    538000.0
# 2    180000.0
# 3    604000.0
# 4    510000.0
# Name: price, dtype: float64
